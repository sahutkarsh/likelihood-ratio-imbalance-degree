# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
palette = ['red', 'green', 'blue', 'cyan', 'magenta', 'orange', 'yellow', 'lightgreen', 'skyblue', 'orchid']

# %%
means_balanced = [[-3,2], [-1.5, 2], [0, 2], [1.5, 2], [3, 2], [-3, 0], [-1.5, 0], [0, 0], [1.5, 0], [3, 0]]

# %%
gaussian_normal_points = np.random.normal(loc=[0.5,10], scale=[1,1], size=[10, 2])

# %%
def generate_distribution(mean_array, size_per_category):
    points = pd.DataFrame()
    x = []
    y = []
    category = []
    index = 0
    for mean in mean_array:
        gaussian_normal_points = np.random.normal(loc=mean, scale=[1,1], size=[size_per_category, 2])
        x += list(gaussian_normal_points[:, 0])
        y += list(gaussian_normal_points[:, 1])
        category += [index] * size_per_category
        index += 1
    points['x'] = x
    points['y'] = y
    points['category'] = category
    return points

# %%
generate_distribution(means_balanced, 5)
# Out:
#            x         y  category
# 0  -3.279920  1.466627         0
# 1  -3.065489  3.791857         0
# 2  -3.844266  1.676034         0
# 3  -1.590778  1.032771         0
# 4  -3.565344  1.194297         0
# 5  -2.404060  2.762626         1
# 6  -0.716180  1.943689         1
# 7  -1.689172  0.493842         1
# 8  -3.141863  1.104153         1
# 9  -1.349439  3.171685         1
# 10  1.008600 -0.092022         2
# 11 -0.108993  2.548508         2
# 12 -0.983504  2.622257         2
# 13 -1.743557  1.248307         2
# 14 -0.924269  2.500899         2
# 15  2.178947  0.679834         3
# 16  1.800292  2.698524         3
# 17  1.494237  1.535249         3
# 18 -0.019326  1.707914         3
# 19  0.945872  3.575613         3
# 20  2.523927  1.751782         4
# 21  0.760006  2.822444         4
# 22  2.069877  3.671898         4
# 23  2.613963  3.001700         4
# 24  4.198552  3.086386         4
# 25 -3.277166  0.429049         5
# 26 -2.825120 -0.729634         5
# 27 -4.596809 -1.346981         5
# 28 -3.792219  0.463753         5
# 29 -3.801874  0.223930         5
# 30 -1.230633 -0.506046         6
# 31 -1.109282 -0.125354         6
# 32 -1.927735 -0.042468         6
# 33 -1.483412 -1.526949         6
# 34 -0.435025 -2.035315         6
# 35  0.348657  0.784006         7
# 36  1.427317  0.682985         7
# 37  1.309779  0.763344         7
# 38 -1.053537  2.515859         7
# 39  0.737329 -2.011783         7
# 40  1.008114  1.140860         8
# 41  0.823691  0.091570         8
# 42 -0.072690  0.330529         8
# 43  3.278349  2.064949         8
# 44  4.137446  0.038997         8
# 45  3.698105 -1.124784         9
# 46  3.181879  0.974932         9
# 47  2.774725 -0.019308         9
# 48  1.728921  0.567411         9
# 49  3.627698 -1.456124         9

# %%
list(gaussian_normal_points[:, 0])
# Out:
# [0.20650396164390467,
#  -0.9226067173096244,
#  0.6416764142947744,
#  -0.27408616838656763,
#  1.0059010321043873,
#  0.12075044828700787,
#  0.5534485245677355,
#  -0.3018276389178909,
#  0.340446603550757,
#  1.1075032446813455]
